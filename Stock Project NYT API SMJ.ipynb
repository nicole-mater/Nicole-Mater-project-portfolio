# %% [markdown]
# ## Smuckers Company NYT data collection

# %%
import json
import urllib.request
import urllib.parse
import time
import pandas as pd
import pickle

# %% [markdown]
# ### requesting from the NYT API

# %%
# pull all articles relevant to Dunkin' in our time frame

years = range(2020, 2026) # Nov-15-2020 start date to match Google Trends data
allresults_dunk = []
baseurl="https://api.nytimes.com/svc/search/v2/articlesearch.json?"
apikey="GGCXEfbqfbBKk5Aii36FMKPK6De5udGe"

# for loop to iterate through each year in our time frame
for year in years:
    begin = f"{year}0101" # changes the year for the api call for each loop
    end   = f"{year}1231"

    page = 0

    while True:
        pa3 = {"api-key": apikey,
            "q": '"Dunkin\'"',
            "begin_date": begin,
            "end_date": end,
            "page": page}

        
        dunk_url = baseurl + urllib.parse.urlencode(pa3)
        request3 = urllib.request.urlopen(dunk_url).read()
        resd3 = json.loads(request3)
    
        response_block3 = resd3.get("response")
        
        # failsafe troubleshooting for API error
        if response_block3 is None:
            print(f"API returned no response for year {year}, page {page}. Retrying...")
            time.sleep(18)
            continue   # try again
    
        docs3 = response_block3.get("docs")
        
        # indicates end of articles
        if docs3 is None or len(docs3) == 0:
            print(f"Finished year {year}: no more articles at page {page}")
            break
    
        # collect the objects of interest
        for doc in docs3:
            allresults_dunk.append({
                "headline"         : doc.get('headline', {}).get('main', ''),
                "abstract"         : doc.get('abstract', ''),
                "publication_date" : doc.get('pub_date', ''),
                "document_type"    : doc.get('document_type', ''),
                "section_name"     : doc.get('section_name', ''),
                "subsection_name"  : doc.get('subsection_name', '')
            })
       
        page += 1  # scraping every page of articles
        time.sleep(18)  # time delay so we don't hit the article limit
        
    
dunk_df = pd.DataFrame(allresults_dunk)
# Out:
# Finished year 2020: no more articles at page 8
# Finished year 2021: no more articles at page 4
# Finished year 2022: no more articles at page 4
# Finished year 2023: no more articles at page 4
# Finished year 2024: no more articles at page 6
# Finished year 2025: no more articles at page 6

# %%
dunk_df = dunk_df[
    (dunk_df['document_type'] == "article") ]
# filtering the results down to article types only

dunk_df.head
# Out:
# <bound method NDFrame.head of                                               headline  \
# 0    Dunkin’ Brands Is in Talks to Sell Itself and ...
# 1                   Met at Dunkin’, Married at Dunkin’
# 2    Dunkin’ Brands has done well in the pandemic. ...
# 3    Do Dunkin’ and Arby’s Go Together? Private Equ...
# 4               Why Dunkin’ Is Worth Nearly $9 Billion
# ..                                                 ...
# 286                               Crypto’s Connections
# 287  Are Markets Taking the Latest Trump Trade Figh...
# 288  How Sleepy Bucks County Became a Rival to the ...
# 289                         The Super Bowl Ads, Ranked
# 290  What I Found on the 365-Mile Trail of a Lost F...
#
#                                               abstract      publication_date  \
# 0    The parent of Dunkin’ and Baskin Robbins is ne...  2020-10-25T17:25:19Z
# 1    Sugar Good and John Thompson discovered there ...  2020-10-23T09:03:01Z
# 2                                                       2020-10-26T12:58:03Z
# 3    Inspire Brands, backed by Roark Capital, is as...  2020-10-31T00:49:57Z
# 4    The restaurant chain is a pandemic success story.  2020-10-26T11:34:48Z
# ..                                                 ...                   ...
# 286  Three ways that President Trump is deepening c...  2025-02-10T11:41:03Z
# 287  Global markets are in a wait-and-see mode as P...  2025-02-10T13:12:55Z
# 288  First came the Hadids. Then Bradley Cooper. No...  2025-01-11T10:00:53Z
# 289  Here is our critic’s survey of this year’s Sup...  2025-02-07T17:05:38Z
# 290  The Old Leatherman, a sort of real-life Northe...  2025-03-09T09:00:56Z
#
#     document_type section_name subsection_name
# 0         article     Business        DealBook
# 1         article        Style
# 2         article     Business
# 3         article     Business        DealBook
# 4         article     Business        DealBook
# ..            ...          ...             ...
# 286       article     Briefing
# 287       article     Business        DealBook
# 288       article        Style
# 289       article         Arts      Television
# 290       article     Magazine
#
# [281 rows x 6 columns]>

# %%
# pull all articles relevant to Folgers in our time frame

years = range(2020, 2026) # Nov-15-2020 start date to match Google Trends data
allresults_folg = []
baseurl="https://api.nytimes.com/svc/search/v2/articlesearch.json?"
apikey="GGCXEfbqfbBKk5Aii36FMKPK6De5udGe"

time.sleep(6)
# for loop to iterate through each year in our time frame
for year in years:
    begin = f"{year}0101" # changes the year for the api call for each loop
    end   = f"{year}1231"

    page = 0

    while True:
        pa4 = {"api-key": apikey,
            "q": "Folgers",
            "begin_date": begin,
            "end_date": end,
            "page": page}

        
        folg_url = baseurl + urllib.parse.urlencode(pa4)
        request4 = urllib.request.urlopen(folg_url).read()
        resd4 = json.loads(request4)
    
        response_block4 = resd4.get("response")
        
        # failsafe troubleshooting for API error
        if response_block4 is None:
            print(f"API returned no response for year {year}, page {page}. Retrying...")
            time.sleep(18)
            continue   # try again
    
        docs4 = response_block4.get("docs")
        
        # indicates end of articles
        if docs4 is None or len(docs4) == 0:
            print(f"Finished year {year}: no more articles at page {page}")
            break
    
        # collect the objects of interest
        for doc in docs4:
            allresults_folg.append({
                "headline"         : doc.get('headline', {}).get('main', ''),
                "abstract"         : doc.get('abstract', ''),
                "publication_date" : doc.get('pub_date', ''),
                "document_type"    : doc.get('document_type', ''),
                "section_name"     : doc.get('section_name', ''),
                "subsection_name"  : doc.get('subsection_name', '')
            })
       
        page += 1  # scraping every page of articles
        time.sleep(24)  # time delay so we don't hit the article limit
        
    
folg_df = pd.DataFrame(allresults_folg)
# Out:
# Finished year 2020: no more articles at page 1
# Finished year 2021: no more articles at page 2
# Finished year 2022: no more articles at page 1
# Finished year 2023: no more articles at page 1
# Finished year 2024: no more articles at page 2
# Finished year 2025: no more articles at page 1

# %%
folg_df = folg_df[
    (folg_df['document_type'] == "article") ]
# filtering the results down to article types only

folg_df.head
# Out:
# <bound method NDFrame.head of                                              headline  \
# 0   How Shakespeare Paperbacks Made Me Want to Be ...
# 1               Is This a Livestream I See Before Me?
# 2   Maurice Edwards, Busy Figure in Theater and Mu...
# 3   City That Once Guided a Nation Now Shows Its C...
# 4   ‘Minor Feelings’ Rescues Personal Experience F...
# 6                             Is Coffee Good for You?
# 7   A 15-Minute Grocery Delivery That Took 21 Minutes
# 8   Transcript: Ezra Klein Answers Listener Questions
# 9    Transcript: Ezra Klein Interviews Céline Gounder
# 11  ‘The Two Noble Kinsmen’ Review: Shakespeare, W...
# 12  Jason Sudeikis wins best comedic actor for ‘Te...
# 13  A Scholarly Analysis of Shakespeare’s Life Tha...
# 14  Karen Hastie Williams, Barrier-Breaking Lawyer...
# 15  Congress, Vaccine Mandates, Baseball: Your Tue...
# 16  Finding Memories, and Mom’s Sewing Stuff, in a...
# 17  Finding Memories, and Mom’s Sewing Stuff, in a...
# 18  As Overdoses Soar, This State’s Largest Needle...
# 19     The T List: Five Things We Recommend This Week
# 20  Can the Black Rifle Coffee Company Become the ...
# 21  The Real Enforcers of Gender Equity in Sports:...
# 22  Quotation of the Day: Title IX Promised Gender...
# 23  Pat Carroll, TV Mainstay Turned Stage Star, Di...
# 24  ‘Raisin in the Sun’ and ‘The Harder They Come’...
# 25  An open-seat House race in Ohio pits an Akron ...
# 26  BBC suspends its operations in Russia after a ...
# 27   Decoding the Defiance of Henry VIII’s First Wife
# 28                    Diary of a Spelling Bee Fanatic
# 30  The Judge and the Case That Came Back to Haunt...
# 32  Biden and Sunak vow that their countries will ...
# 33  Twinkies and Jam to Mix as Smucker Buys Hostes...
# 34       Why the Humanities Are Indeed Worth Teaching
# 35  ‘Make Noise Enough’: Excavating Shakespeare’s ...
# 36  For Rare Book Librarians, It’s Gloves Off. Ser...
# 37                       Finding Love in a Fake World
# 38  The Absurd, Unsolved Hunt to Find a Definitive...
# 39  The Folger Library Wants to Reintroduce You to...
# 40  Assassination of a top Hamas leader spurs rall...
# 41  Who Are the Key Players in the Alec Baldwin Ma...
# 42  Trump’s Message: Prices (Plus Gangs, A.I. and ...
# 43              Why Coffee Prices Are Soaring (Again)
# 44  Browsing Is a Pleasure in This History of the ...
# 45               Who’s Afraid of William Shakespeare?
# 47  Summer Reading Contest, Week 4: What Got Your ...
# 48  Jeffrey Wright: Hiding in Plain Sight in Our F...
# 50  A Major Test of Presidential Power, and How St...
# 52  How Much Do You Really Want to Know About Your...
# 53                           Word of the Day: coterie
# 54  Sightings of federal immigration vehicles prom...
# 55  Former Member of Murderous Manson Crew Is Reco...
# 56         Their Families Are Famous. Or So They Say.
# 57  Coffee Prices Are at a 50-Year High. Producers...
# 58  Skip the Beach: 5 Cities Where Adults and Kids...
# 59       The 13 Greatest ‘S.N.L.’ Commercial Parodies
#
#                                              abstract      publication_date  \
# 0   The more you read, the more you realize Shakes...  2020-06-02T09:00:10Z
# 1   All the world with an internet connection has ...  2020-05-13T14:00:08Z
# 2   He was involved with the Brooklyn Philharmonic...  2020-10-08T17:45:35Z
# 3   Peoria, Ill., was a place where marketers and ...  2020-07-01T09:00:48Z
# 4   In this collection of essays, Cathy Park Hong ...  2020-02-17T10:00:01Z
# 6   Yes! But it depends on the kind of coffee and ...  2020-02-13T19:32:41Z
# 7                                                      2021-11-10T08:57:03Z
# 8                                                      2021-08-31T18:50:04Z
# 9                                                      2021-08-06T14:03:04Z
# 11  The Drilling Company returns to live theater w...  2021-07-22T17:57:29Z
# 12                                                     2021-02-28T23:32:50Z
# 13  James Shapiro reviews Lena Cowen Orlin’s book,...  2021-11-23T10:00:03Z
# 14  She was the first Black woman to serve as a Su...  2021-08-08T15:02:04Z
# 15  Here’s what you need to know at the end of the...  2021-09-28T21:47:51Z
# 16  The containers we use over and over, from Cool...  2021-09-27T09:00:15Z
# 17  The containers we use over and over, from Cool...  2021-09-27T09:00:15Z
# 18  Syringe-access sites have been proven to reduc...  2021-08-10T09:00:26Z
# 19  Casual separates, wallpaper inspired by the ho...  2021-03-25T13:00:13Z
# 20  The company doubled its sales last year by lea...  2021-07-14T09:00:21Z
# 21  Girls are supposed to have equal access in sch...  2022-06-22T09:00:23Z
# 22    Quotation of the Day for Friday, June 24, 2022.  2022-06-24T04:36:03Z
# 23  Tired of sitcoms and game shows, she reinvente...  2022-07-31T22:57:15Z
# 24  Two new works by Suzan-Lori Parks will be incl...  2022-06-14T18:13:07Z
# 25  Emilia Sykes, who led Ohio’s House Democrats, ...  2022-05-04T02:50:02Z
# 26                                                     2022-03-04T17:30:39Z
# 27  Using a process she called “early modern Wordl...  2022-07-07T15:33:10Z
# 28              Entries for the week of May 16, 2022.  2022-05-21T13:00:04Z
# 30  In 1981, Anthony Kline helped send a juvenile ...  2022-11-21T10:00:36Z
# 32                                                  .  2023-06-08T21:50:05Z
# 33  J.M. Smucker, the maker of jellies, Jif peanut...  2023-09-11T16:29:39Z
# 34  Readers respond to a guest essay by a philosop...  2023-12-30T16:00:09Z
# 35  In Shakespeare, music is an integral part of t...  2023-10-26T15:35:52Z
# 36  When handling rare books, experts say that bar...  2023-03-09T10:02:41Z
# 37  Julia Argy’s debut novel, “The One,” goes behi...  2023-04-18T09:00:08Z
# 38  In “Stalking Shakespeare,” Lee Durkee describe...  2023-04-15T09:00:13Z
# 39  After an $80 million expansion, the Folger Sha...  2024-06-21T16:00:12Z
# 40                                                  .  2024-07-31T23:39:18Z
# 41                                                  ‎  2024-07-09T14:50:04Z
# 42  Former President Donald J. Trump was supposed ...  2024-08-16T17:32:40Z
# 43  Wholesale coffee prices are trading near a 50-...  2024-12-28T10:00:56Z
# 44  “People feel differently about their bookstore...  2024-08-04T09:00:54Z
# 45  We will always need the works of the Bard, esp...  2024-10-21T09:00:45Z
# 47  To participate, submit your response here by J...  2024-06-28T12:58:12Z
# 48  The veteran has played everything from an arti...  2024-02-13T15:18:09Z
# 50            Plus, the social changes sweeping Iran.  2025-12-08T11:00:09Z
# 52  Spotify is not the only company quantifying ou...  2025-12-03T13:00:06Z
# 53  This word has appeared in 86 articles on NYTim...  2025-11-26T07:00:02Z
# 54                                                     2025-06-09T00:46:42Z
# 55  Patricia Krenwinkel, 77, who was part of what ...  2025-05-31T22:52:52Z
# 56  As part of a social media trend, some people a...  2025-05-29T19:30:05Z
# 57  Climate change is behind the windfall gains, a...  2025-02-22T05:00:33Z
# 58  These North American cities have walkable down...  2025-02-14T10:00:29Z
# 59  To us, anyway. Over 50 seasons, “Saturday Nigh...  2025-01-18T10:01:04Z
#
#    document_type          section_name subsection_name
# 0        article              Magazine
# 1        article               Theater
# 2        article                  Arts           Music
# 3        article              Business
# 4        article                 Books
# 6        article                 Style       Self-Care
# 7        article              New York
# 8        article              Podcasts
# 9        article              Podcasts
# 11       article               Theater
# 12       article                Movies
# 13       article                 Books     Book Review
# 14       article            Obituaries
# 15       article              Briefing
# 16       article                  Food
# 17       article                  Food
# 18       article              New York
# 19       article            T Magazine
# 20       article              Magazine
# 21       article                Sports
# 22       article         Today’s Paper
# 23       article                  Arts      Television
# 24       article               Theater
# 25       article                  U.S.       Elections
# 26       article                 World          Europe
# 27       article                  Arts
# 28       article              Gameplay
# 30       article              Magazine
# 32       article                 World          Europe
# 33       article              Business
# 34       article               Opinion
# 35       article                  Arts           Music
# 36       article                  Arts
# 37       article                 Books     Book Review
# 38       article                 Books     Book Review
# 39       article                  Arts
# 40       article                 World     Middle East
# 41       article                Movies
# 42       article                  U.S.        Politics
# 43       article              Business
# 44       article                 Books     Book Review
# 45       article               Opinion
# 47       article  The Learning Network
# 48       article                Movies
# 50       article              Podcasts   The Headlines
# 52       article                 Style
# 53       article  The Learning Network
# 54       article                  U.S.
# 55       article                  U.S.
# 56       article                 Style
# 57       article              Business
# 58       article                Travel
# 59       article                  Arts      Television  >

# %%
smj_df = pd.concat([dunk_df, folg_df], ignore_index=True)
# combine the articles related to Dunkin' and those related to Folgers

# %%
smj_df = smj_df[
    smj_df['headline'].str.contains("Dunkin", case=False, na=False) |
    smj_df['abstract'].str.contains("Dunkin", case=False, na=False) |
    smj_df['headline'].str.contains("Folgers", case=False, na=False)|
    smj_df['abstract'].str.contains("Folgers", case=False, na=False)]
# filtering the output so the headline or abstract include the company name (Dunkin' or Folgers)

smj_df.head
# Out:
# <bound method NDFrame.head of                                               headline  \
# 0    Dunkin’ Brands Is in Talks to Sell Itself and ...
# 1                   Met at Dunkin’, Married at Dunkin’
# 2    Dunkin’ Brands has done well in the pandemic. ...
# 3    Do Dunkin’ and Arby’s Go Together? Private Equ...
# 4               Why Dunkin’ Is Worth Nearly $9 Billion
# 5    Meet the private equity firm trying to buy Dun...
# 20   CVS, Dunkin’, Lego: The Brands Pulling Ads Fro...
# 112  Customer’s Racial Slur Drew a Fatal Punch. The...
# 149    Restaurant Chains Make It Cost More to Be Loyal
# 179        No Interviewing Voters in a Dunkin’ Donuts!
# 183  How Alarmed Harris Staffers Went Rogue to Reac...
# 229  2 Million Baked Goods Are Recalled Over Lister...
#
#                                               abstract      publication_date  \
# 0    The parent of Dunkin’ and Baskin Robbins is ne...  2020-10-25T17:25:19Z
# 1    Sugar Good and John Thompson discovered there ...  2020-10-23T09:03:01Z
# 2                                                       2020-10-26T12:58:03Z
# 3    Inspire Brands, backed by Roark Capital, is as...  2020-10-31T00:49:57Z
# 4    The restaurant chain is a pandemic success story.  2020-10-26T11:34:48Z
# 5                                                       2020-10-27T12:44:45Z
# 20   An effort to pressure Facebook to crack down o...  2020-06-26T20:49:39Z
# 112  A plea deal in a confrontation at a Dunkin’ sh...  2022-03-10T03:16:39Z
# 149  Recent changes to rewards programs at places l...  2023-02-28T10:00:25Z
# 179  But there is always another one a few blocks a...  2024-01-23T15:20:40Z
# 183  Worried that the campaign was neglecting voter...  2024-12-07T10:02:36Z
# 229  The recall, which was initiated on Jan. 7 and ...  2025-02-09T18:40:19Z
#
#     document_type section_name subsection_name
# 0         article     Business        DealBook
# 1         article        Style
# 2         article     Business
# 3         article     Business        DealBook
# 4         article     Business        DealBook
# 5         article     Business
# 20        article     Business           Media
# 112       article         U.S.
# 149       article     Business
# 179       article      Opinion
# 183       article         U.S.        Politics
# 229       article       Health                  >

# %% [markdown]
# ### Sentiment analysis

# %%
from nltk.sentiment.vader import SentimentIntensityAnalyzer
sia = SentimentIntensityAnalyzer()
# combine the headline and abstract into one field for sentiment analysis
smj_df['text'] = smj_df['headline'] + " " + smj_df['abstract']
# Out:
# /tmp/ipykernel_562599/2876307098.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   smj_df['text'] = smj_df['headline'] + " " + smj_df['abstract']

# %%
sent_pos4 = []
sent_neg4 = []
sent_neu4 = []
sent_comp4 = []
corpus4 = smj_df['text']

# iterate through each sentence in corpus
for article in corpus4:
    
    # analyze the sentiment. ss is a dictionary
    ss = sia.polarity_scores(article)

    # append and store these sentiment scores into a list
    sent_neg4.append(ss['neg'])
    sent_neu4.append(ss['neu'])
    sent_comp4.append(ss['compound'])

# %%
# adding the list to the dataframe as column using assign(column_name = data)
smj_df = smj_df.assign(article_pos = sent_pos4)
smj_df = smj_df.assign(article_neg = sent_neg4)
smj_df = smj_df.assign(article_neu = sent_neu4)
smj_df = smj_df.assign(article_comp = sent_comp4)

# %% [markdown]
# ### Summarizing data

# %%
smj_df = smj_df.copy()
smj_df['publication_date'] = pd.to_datetime(smj_df['publication_date'])

# find the Friday of the week for each publication date
smj_df['fiscal_week'] = smj_df['publication_date'] + pd.offsets.Week(weekday=4)
smj_df['fiscal_week'] = smj_df['fiscal_week'].dt.date

# %%
weekly_df_smj = (
    smj_df.groupby('fiscal_week')
          .agg(
              article_count = ('text', 'count'),
              pos_sentiment  = ('article_pos', 'sum'),
              neg_sentiment  = ('article_neg', 'sum'),
              neu_sentiment  = ('article_neu', 'sum'),
              comp_sentiment = ('article_comp', 'mean'),
          )
          .reset_index()
)
# group the rest of the columns by summing or averaging the values for the week

# %%
# create ratios to analyze article sentiment
# total
weekly_df_smj['total_sent'] = weekly_df_smj['pos_sentiment'] + weekly_df_smj['neg_sentiment'] + weekly_df_smj['neu_sentiment']
# ratios
weekly_df_smj['pos_ratio'] = weekly_df_smj['pos_sentiment'] / weekly_df_smj['total_sent']
weekly_df_smj['neg_ratio'] = weekly_df_smj['neg_sentiment'] / weekly_df_smj['total_sent']

weekly_df_smj = weekly_df_smj.drop(columns=['total_sent', 'pos_sentiment', 'neg_sentiment', 'neu_sentiment'])

# %%
# final dataset
weekly_df_smj.head
# Out:
# <bound method NDFrame.head of   fiscal_week  article_count  comp_sentiment  pos_ratio  neg_ratio
# 0  2020-07-03              1        -0.92010   0.000000   0.256000
# 1  2020-10-30              5         0.33482   0.119600   0.007200
# 2  2020-11-06              1         0.58590   0.134000   0.000000
# 3  2022-03-11              1        -0.78450   0.032032   0.202202
# 4  2023-03-03              1         0.73220   0.220000   0.093000
# 5  2024-01-26              1        -0.50100   0.000000   0.246000
# 6  2024-12-13              1        -0.83600   0.024000   0.217000
# 7  2025-02-14              1         0.17790   0.094000   0.070000>

# %%
weekly_df_smj.to_csv("smj_nyt_data.csv", index=False)
